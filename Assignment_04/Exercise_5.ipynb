# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the number of points and the x values
num_points = 1000001
x_values = np.linspace(-5, 5, num_points)
print(x_values)
# Compute the function values using NumPy vectorization
def f(x):
    return np.where(x < 0, x * np.sin(x**2), np.cos(x))

y_values = f(x_values)
print("All values for x__values:",y_values)
# Plot the function
plt.figure(figsize=(10, 6))
plt.plot(x_values, y_values, label='f(x)')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.title('Plot of the Function f(x)')
plt.show()
# Out:
# [-5.      -4.99999 -4.99998 ...  4.99998  4.99999  5.     ]
# All values for x__values: [0.66175875 0.66225302 0.66274729 ... 0.28364301 0.2836526  0.28366219]
