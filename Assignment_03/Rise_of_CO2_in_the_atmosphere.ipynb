# %% [markdown]
# <a href="https://colab.research.google.com/github/shubhams821/ma22c043_2023_PL/blob/main/Assignment_3/Rise_of_CO2_in_the_atmosphere.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np       #importing necessary libraries

# %%
df = pd.read_csv('/content/co2_mm_mlo.csv')

# %%
df.head
# Out:
# <bound method NDFrame.head of      1958  3  1958.2027  315.70  314.43  -1  -9.99  -0.99
# 0    1958  4  1958.2877  317.45  315.16  -1  -9.99  -0.99
# 1    1958  5  1958.3699  317.51  314.71  -1  -9.99  -0.99
# 2    1958  6  1958.4548  317.24  315.14  -1  -9.99  -0.99
# 3    1958  7  1958.5370  315.86  315.18  -1  -9.99  -0.99
# 4    1958  8  1958.6219  314.93  316.18  -1  -9.99  -0.99
# ..    ... ..        ...     ...     ...  ..    ...    ...
# 778  2023  2  2023.1250  420.30  419.37  23   0.71   0.28
# 779  2023  3  2023.2083  420.98  419.53  30   0.74   0.26
# 780  2023  4  2023.2917  423.36  420.67  28   0.60   0.22
# 781  2023  5  2023.3750  424.00  420.54  31   0.69   0.24
# 782  2023  6  2023.4583  423.68  421.26  29   0.54   0.19
#
# [783 rows x 8 columns]>

# %%
arr_df = np.array(df)
print('dimesion of data',arr_df.shape) #creating array for faster calculation.
# Out:
# dimesion of data (783, 8)

# %%
arr_df
# Out:
# array([[ 1.9580000e+03,  4.0000000e+00,  1.9582877e+03, ...,
#         -1.0000000e+00, -9.9900000e+00, -9.9000000e-01],
#        [ 1.9580000e+03,  5.0000000e+00,  1.9583699e+03, ...,
#         -1.0000000e+00, -9.9900000e+00, -9.9000000e-01],
#        [ 1.9580000e+03,  6.0000000e+00,  1.9584548e+03, ...,
#         -1.0000000e+00, -9.9900000e+00, -9.9000000e-01],
#        ...,
#        [ 2.0230000e+03,  4.0000000e+00,  2.0232917e+03, ...,
#          2.8000000e+01,  6.0000000e-01,  2.2000000e-01],
#        [ 2.0230000e+03,  5.0000000e+00,  2.0233750e+03, ...,
#          3.1000000e+01,  6.9000000e-01,  2.4000000e-01],
#        [ 2.0230000e+03,  6.0000000e+00,  2.0234583e+03, ...,
#          2.9000000e+01,  5.4000000e-01,  1.9000000e-01]])

# %%
x = arr_df[:,2]
y = arr_df[:,3]
xnew = np.linspace(1958.2877 ,2023.4583, num=783)
ynew = np.interp(xnew, x, y)                     # data has inconsistence gaps for which we require to interpolate it.

# %%
import matplotlib.pyplot as plt
plt.plot(xnew, ynew, '-', label='linear interp')
plt.legend(loc='best')
plt.show()

# %%
plt.plot(x, y,'-', label='data')
plt.legend(loc='best')

# %%
xnew[:10],x[:10]
# Out:
# (array([1958.2877    , 1958.37103836, 1958.45437673, 1958.53771509,
#         1958.62105345, 1958.70439182, 1958.78773018, 1958.87106854,
#         1958.95440691, 1959.03774527]),
#  array([1958.2877, 1958.3699, 1958.4548, 1958.537 , 1958.6219, 1958.7068,
#         1958.789 , 1958.874 , 1958.9562, 1959.0411]))

# %%
ynew[:10],y[:10]
# Out:
# (array([317.45      , 317.50637976, 317.2413461 , 315.85216686,
#         314.93927313, 313.24907136, 312.44189492, 313.29896104,
#         314.6407695 , 315.54404234]),
#  array([317.45, 317.51, 317.24, 315.86, 314.93, 313.2 , 312.43, 313.33,
#         314.67, 315.58]))

# %%
h = (1958.2877 -2023.4583)/783

# %%
rate_of_change = [(ynew[i]-ynew[i-1]) for i in range(1,783)]

# %%
rate_of_change[:10]
# Out:
# [0.056379763765392,
#  -0.26503366379569115,
#  -1.3891792359908095,
#  -0.9128937308519198,
#  -1.6902017719054356,
#  -0.807176444575191,
#  0.8570661184070332,
#  1.3418084685583835,
#  0.9032728329434008,
#  0.8838406851445484]

# %%
plt.plot(xnew[1:],rate_of_change,'-')

# %% [markdown]
# The height of oscillation increases with time which shows that CO2 increases and decreases with time, although CO2 data has a rising trend,

# %%
# Out:
# array([ 1.16379764e-01, -5.35033664e-01, -2.76917924e+00, -1.84289373e+00,
#        -3.42020177e+00, -1.57717644e+00,  1.75706612e+00,  2.68180847e+00,
#         1.81327283e+00,  1.78384069e+00,  4.13793855e-01,  2.11874166e+00,
#         1.13760477e+00, -2.77424863e-01, -3.23649101e+00, -3.44799472e+00,
#        -1.90956486e+00, -1.03904389e+00,  2.90250512e+00,  1.57375968e+00,
#         1.68421216e+00,  1.10243459e+00,  1.22642049e+00,  2.87270400e+00,
#         2.04502914e+00, -8.84992395e-01, -2.82159487e+00, -4.51883318e+00,
#        -3.44404457e+00, -7.37842887e-01,  2.28976866e+00,  2.39724900e+00,
#         1.39902522e+00,  1.60094231e+00,  1.74613179e+00,  1.86204492e+00,
#         2.18498859e+00, -1.60510099e+00, -2.42109956e+00, -3.52725897e+00,
#        -3.56673433e+00,  5.88543690e-01,  1.55867604e+00,  1.82771642e+00,
#         1.84308152e+00,  1.22074172e+00,  2.31394898e+00,  1.76139546e+00,
# ...
